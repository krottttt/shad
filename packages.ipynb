# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.7.0
# appnope                   0.1.2
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# Brotli                    1.0.9
# certifi                   2025.4.26
# cffi                      1.17.1
# charset-normalizer        3.3.2
# comm                      0.2.1
# debugpy                   1.8.11
# decorator                 5.1.1
# defusedxml                0.7.1
# exceptiongroup            1.2.0
# executing                 0.8.3
# fastjsonschema            2.20.0
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.7
# ipykernel                 6.29.5
# ...

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# !pip install pytorch
# !pip install scipy
# !pip install seaborn
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 13.5 MB/s eta 0:00:00 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [seaborn]m3/4 [seaborn]
# ...

# %%
# !pip install numba
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 2.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 6.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [numba]32m1/2 [numba]
# ...
